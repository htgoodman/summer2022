# %%
#Standard Library Imports. 
import numpy as np
import matplotlib.pyplot as plt

# %%
import astropy
from astropy.io import fits

# %%
fits_image_filename = 'mangaHIall_dr3GOOD_rc_parameters_yyoon.fits'

# %%
astropy.io.fits.open('mangaHIall_dr3GOOD_rc_parameters_yyoon.fits')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1398/3828975841.py in <module>
# ----> 1 astropy.io.fits.open('mangaHIall_dr3GOOD_rc_parameters_yyoon.fits')
#
# ~/miniconda3/envs/py38/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     174         raise ValueError(f'Empty filename: {name!r}')
#     175
# --> 176     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#     177                             lazy_load_hdus, ignore_missing_simple, **kwargs)
#     178
#
# ~/miniconda3/envs/py38/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     409         """
#     410
# ...

# %%
hdul = fits.open(fits_image_filename)

# %%
hdul

# %%
hdul.info()
# Out:
# Filename: mangaHIall_dr3GOOD_rc_parameters_yyoon.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      16   (3460,)   uint8
#   1  Joined        1 BinTableHDU     92   80R x 40C   [11A, D, D, D, D, D, D, D, D, 9A, D, D, E, 79A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, I, I, D]

# %%
hdul.close()

# %%
with fits.open(fits_image_filename) as hdul:
    hdul.info()
# Out:
# Filename: mangaHIall_dr3GOOD_rc_parameters_yyoon.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      16   (3460,)   uint8
#   1  Joined        1 BinTableHDU     92   80R x 40C   [11A, D, D, D, D, D, D, D, D, 9A, D, D, E, 79A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, I, I, D]

# %%
with fits.open(fits_image_filename) as hdul:
    data = hdul[1].data
    data

# %%
len(data)
# Out:
# 80

# %%
data
# Out:
# FITS_rec([('10213-9101', 122.36352  ,  4.3934918e+01, 207.03249 , 3.7470374 , -3.6288854e+00, -9.9420569e+00, 64.449786, 161.11613   , '1-44999',  9.91829618, 0.82632782,  6884.2   , 'AGBT17A_012_340',  846.18695, 1.7190437 , -999., 0.01947592, 10.329507 , 4.07699  , 0.15571973,  9.96224 ,  6874.3486,  4.78287  ,  343.6021 ,  333.9316 , 348.96988,  334.0506  , 335.87897 ,    7.5238743,   16.22993 ,   16.028118,  109.80094 ,  5.8300972e-01,  102.230255, -5.4048181e-01, 0, 0, 0, 0.),
#           ('10214-1902', 121.98829  ,  3.4227327e+01,  26.348096, 0.4287873 ,  4.4978814e+00, -2.9142451e+00, 31.790592, 276.26228   , '1-153402',  9.48339614, 0.38640048,  6528.5   , 'AGBT19A_127_26',  766.1663 , 1.3827271 , -999., 0.01663199, 11.028398 , 2.062905 , 0.0925824 ,  9.623957,  6544.464 ,  7.5590158,  149.48021,  135.992  , 162.12325,  136.53485 , 141.10814 ,    7.851486 ,   13.094404,   13.859993,   40.737713,  4.5684454e-01,   20.681894, -1.8827482e-01, 0, 0, 0, 0.),
# ...

# %%
data.columns
# Out:
# ColDefs(
#     name = 'PLATEIFU'; format = '11A'
#     name = 'RA'; format = 'D'
#     name = 'DEC'; format = 'D'
#     name = 'V_c'; format = 'D'
#     name = 'R_t'; format = 'D'
#     name = 's_out'; format = 'D'
#     name = 'V_sys'; format = 'D'
#     name = 'Incl'; format = 'D'
#     name = 'Phi0'; format = 'D'
#     name = 'MANGAID'; format = '9A'
#     name = 'LOGMSTARS'; format = 'D'
#     name = 'SINI'; format = 'D'
#     name = 'VOPT'; format = 'E'
#     name = 'SESSION'; format = '79A'
#     name = 'EXP'; format = 'E'
#     name = 'RMS'; format = 'E'
#     name = 'LOGHILIM200KMS'; format = 'E'
#     name = 'PEAK'; format = 'E'
#     name = 'SNR'; format = 'E'
#     name = 'FHI'; format = 'E'
#     name = 'EFHI'; format = 'E'
#     name = 'LOGMHI'; format = 'E'
#     name = 'VHI'; format = 'E'
#     name = 'EV'; format = 'E'
#     name = 'WM50'; format = 'E'
#     name = 'WP50'; format = 'E'
#     name = 'WP20'; format = 'E'
#     name = 'W2P50'; format = 'E'
# ...

# %%
data[0]
# Out:
# ('10213-9101', 122.36352, 43.934918, 207.03249, 3.7470374, -3.6288854, -9.9420569, 64.449786, 161.11613, '1-44999', 9.918296182095766, 0.8263278165929279, 6884.2, 'AGBT17A_012_340', 846.18695, 1.7190437, -999.0, 0.019475918, 10.329507, 4.07699, 0.15571973, 9.96224, 6874.3486, 4.78287, 343.6021, 333.9316, 348.96988, 334.0506, 335.87897, 7.5238743, 16.22993, 16.028118, 109.80094, 0.5830097, 102.230255, -0.5404818, 0, 0, 0, 0.0)

# %%
import pandas as pd

# %%
df = pd.read_csv('forbidden.txt', delimiter=',')

# %%
df
# Out:
#                    PLATEIFU          RA        DEC         V_c       R_t  \
# 0             ('10213-9101'  122.363520  43.934918  207.032490  3.747037
# 1             ('10214-1902'  121.988290  34.227327   26.348096  0.428787
# 2             ('10214-6101'  123.061820  35.157138   29.521736  0.996485
# 3             ('10224-3702'   34.921377  -0.255641  195.666800  1.386220
# 4             ('10503-9102'  159.873810   5.795395  126.402330  2.335520
# ..                      ...         ...        ...         ...       ...
# 75            ('9500-12702'  132.598330  25.954082  169.264310  3.245579
# 76             ('9502-9102'  129.030900  25.112727  120.809450  2.801706
# 77             ('9504-3703'  123.872820  29.821746   25.297445  0.807813
# 78             ('9506-9102'  135.090250  27.980266  143.172170  3.883820
# 79            ('9882-12705'  207.781130  24.018234  173.268400  2.637309
#
#         s_out      V_sys       Incl        Phi0      MANGAID  ...          PL  \
# ...

# %%
df.columns[1:4]
# Out:
# Index([' RA', ' DEC', ' V_c'], dtype='object')

# %%
df.iloc[1:4]
# Out:
#                   PLATEIFU          RA        DEC         V_c       R_t  \
# 1            ('10214-1902'  121.988290  34.227327   26.348096  0.428787
# 2            ('10214-6101'  123.061820  35.157138   29.521736  0.996485
# 3            ('10224-3702'   34.921377  -0.255641  195.666800  1.386220
#
#        s_out      V_sys       Incl        Phi0      MANGAID  ...         PL  \
# 1   4.497881  -2.914245  31.790592  276.262280   '1-153402'  ...  13.859993
# 2   0.472039 -19.741566  49.908095   67.802374   '1-153412'  ...  16.878800
# 3 -16.729959  15.509460  28.378273  116.179080    '1-35926'  ...  17.698526
#
#           AR        BR         AL        BL   NEGDET   BLSTRUCT   conflag  \
# 1  40.737713  0.456845  20.681894 -0.188275        0          0         0
# 2  23.535063  0.160623  46.323840 -0.320513        0          0         0
# 3  68.307430  0.573168  59.911446 -0.517281        0          0         0
#
#     conf_prob  Unnamed: 40
# 1         0.)          NaN
# ...

# %%
df[:5]
# Out:
#                   PLATEIFU          RA        DEC         V_c       R_t  \
# 0            ('10213-9101'  122.363520  43.934918  207.032490  3.747037
# 1            ('10214-1902'  121.988290  34.227327   26.348096  0.428787
# 2            ('10214-6101'  123.061820  35.157138   29.521736  0.996485
# 3            ('10224-3702'   34.921377  -0.255641  195.666800  1.386220
# 4            ('10503-9102'  159.873810   5.795395  126.402330  2.335520
#
#        s_out      V_sys       Incl        Phi0      MANGAID  ...          PL  \
# 0  -3.628885  -9.942057  64.449786  161.116130    '1-44999'  ...   16.028118
# 1   4.497881  -2.914245  31.790592  276.262280   '1-153402'  ...   13.859993
# 2   0.472039 -19.741566  49.908095   67.802374   '1-153412'  ...   16.878800
# 3 -16.729959  15.509460  28.378273  116.179080    '1-35926'  ...   17.698526
# 4  -4.408972   6.621953  30.179515   87.346090   '1-183743'  ... -999.000000
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['PLATEIFU', ' RA', ' DEC', ' V_c', ' R_t', ' s_out', 'V_sys', ' Incl', ' Phi0', ' MANGAID', ' LOGMSTARS', ' SINI', ' VOPT', ' SESSION', ' EXP', ' RMS', ' LOGHILIM200KMS', ' PEAK', ' SNR', ' FHI', ' EFHI', ' LOGMHI', ' VHI', ' EV', ' WM50', ' WP50', ' WP20', ' W2P50', ' WF50', ' DW', ' PR', ' PL', ' AR', ' BR', ' AL', ' BL', ' NEGDET', ' BLSTRUCT', ' conflag', ' conf_prob', 'Unnamed: 40']

# %%
df['PLATEIFU']
# Out:
# 0               ('10213-9101'
# 1               ('10214-1902'
# 2               ('10214-6101'
# 3               ('10224-3702'
# 4               ('10503-9102'
#                ...
# 75              ('9500-12702'
# 76               ('9502-9102'
# 77               ('9504-3703'
# 78               ('9506-9102'
# 79              ('9882-12705'
# Name: PLATEIFU, Length: 80, dtype: object

# %%
df[' RA']
# Out:
# 0     122.363520
# 1     121.988290
# 2     123.061820
# 3      34.921377
# 4     159.873810
#          ...
# 75    132.598330
# 76    129.030900
# 77    123.872820
# 78    135.090250
# 79    207.781130
# Name:  RA, Length: 80, dtype: float64

# %%
df.loc[df[' Incl']>70]
# Out:
#                     PLATEIFU          RA        DEC         V_c       R_t  \
# 11            ('11743-12705'  118.518730  13.954120  109.542530  3.401793
# 31              ('8089-6101'    6.401983  14.115274   31.407507  2.040309
# 32             ('8131-12701'  111.107940  38.945215   44.873675  2.024364
# 76              ('9502-9102'  129.030900  25.112727  120.809450  2.801706
# 78              ('9506-9102'  135.090250  27.980266  143.172170  3.883820
#
#        s_out      V_sys       Incl       Phi0      MANGAID  ...          PL  \
# 11  4.076348 -11.129875  70.934723  146.76550   '1-604873'  ... -999.000000
# 31  2.268946  -6.984865  84.145857  211.43421   '1-120697'  ... -999.000000
# 32  3.677250  17.964024  74.494996  184.54342   '1-584473'  ...   24.210705
# 76  0.184838   4.022161  70.295674   79.66884   '1-385129'  ... -999.000000
# 78  0.682183  -3.363937  73.781933  241.88795   '1-386298'  ... -999.000000
#
# ...

# %%
df.loc[df[' V_c']>150]
# Out:
#                     PLATEIFU          RA        DEC        V_c       R_t  \
# 0              ('10213-9101'  122.363520  43.934918  207.03249  3.747037
# 3              ('10224-3702'   34.921377  -0.255641  195.66680  1.386220
# 9             ('11004-12705'  196.117630  26.671955  208.47741  2.520044
# 13             ('11945-6101'  251.045050  39.788762  154.11506  2.714537
# 14            ('11960-12701'  236.536690   8.792879  150.44385  2.770881
# 15             ('11974-3703'  238.811370  10.521325  150.50231  2.101106
# 19             ('12085-9102'  345.667960  13.329092  171.73582  1.896972
# 21             ('12484-6102'  196.420960  33.178917  210.06975  1.270975
# 27             ('12621-6103'  204.691160  30.480449  159.37450  2.195422
# 33             ('8137-12703'  116.169260  44.144409  182.43294  3.606560
# 36             ('8147-12703'  118.592630  27.008804  153.80479  4.048957
# 48              ('8482-3702'  245.089660  49.943491  302.97634  1.870276
# ...

# %%
df.loc[df[' V_c']<70]
# Out:
#                    PLATEIFU          RA        DEC        V_c       R_t  \
# 1             ('10214-1902'  121.988290  34.227327  26.348096  0.428787
# 2             ('10214-6101'  123.061820  35.157138  29.521736  0.996485
# 7             ('10844-3703'  146.397710   4.410584  32.393385  1.056539
# 12            ('11828-3703'  163.266020   4.631867  66.962706  1.536172
# 26            ('12620-9101'  201.177420  29.049612  66.842333  2.298592
# 31             ('8089-6101'    6.401983  14.115274  31.407507  2.040309
# 32            ('8131-12701'  111.107940  38.945215  44.873675  2.024364
# 34            ('8140-12704'  117.923770  42.303574  57.888471  4.099707
# 35             ('8145-6103'  116.503040  28.699634  34.998522  1.317621
# 37             ('8148-9101'  117.902070  27.379675  49.425498  3.042655
# 41            ('8329-12704'  213.783650  45.594849  67.965915  2.235556
# 43             ('8438-9101'  148.052870  17.593560  49.951636  1.922673
# ...

# %%
hi_turnover_radii = df.loc[df[' R_t']>3.5] #where the turnover radius is larger than 3.5 arcseconds 
hi_turnover_radii
# Out:
#                     PLATEIFU         RA        DEC         V_c       R_t  \
# 0              ('10213-9101'  122.36352  43.934918  207.032490  3.747037
# 5             ('10515-12704'  148.03445   4.252317  138.942560  4.267064
# 18            ('12084-12702'  344.89937  14.089555  107.269330  4.305615
# 20            ('12089-12702'  351.92856  14.544752  144.563410  3.841654
# 33             ('8137-12703'  116.16926  44.144409  182.432940  3.606560
# 34             ('8140-12704'  117.92377  42.303574   57.888471  4.099707
# 36             ('8147-12703'  118.59263  27.008804  153.804790  4.048957
# 59             ('8983-12705'  203.91004  25.875237  113.513120  4.017350
# 67             ('9090-12704'  243.90381  28.158585  139.370950  3.859290
# 69             ('9093-12705'  242.40634  28.051843   70.347382  3.728050
# 72             ('9493-12701'  128.19586  22.576563  131.376120  4.767811
# 73              ('9494-9102'  127.43484  22.424396  109.702930  3.596196
# ...
